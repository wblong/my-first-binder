# %%
import urllib.request
link = 'https://sqlite.org/2020/sqlite-amalgamation-3330000.zip'
f=urllib.request.urlopen(link)
with open("sqlite-amalgamation-3330000.zip", "wb") as code:
    code.write(f.read())
print("test")
# Out:
# test
